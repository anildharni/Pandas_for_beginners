# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.options.display.mpl_style = 'default'
# Out:
# C:\Users\user\anaconda_new\lib\site-packages\IPython\core\interactiveshell.py:2881: FutureWarning:
# mpl_style had been deprecated and will be removed in a future version.
# Use `matplotlib.pyplot.style.use` instead.
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
a = pd.Series(np.random.randn(1000),index = (pd.date_range('20170720',periods =1000)))

# %%
b = a.cumsum()

# %%
b
# Out:
# 2017-07-20     0.874626
# 2017-07-21     0.413204
# 2017-07-22     1.790967
# 2017-07-23     2.267998
# 2017-07-24     3.513710
# 2017-07-25     4.096963
# 2017-07-26     2.692731
# 2017-07-27     3.664749
# 2017-07-28     4.688723
# 2017-07-29     4.036194
# 2017-07-30     3.584100
# 2017-07-31     3.983320
# 2017-08-01     4.755650
# 2017-08-02     4.321801
# 2017-08-03     4.813326
# 2017-08-04     5.048447
# 2017-08-05     5.269264
# 2017-08-06     5.961548
# 2017-08-07     7.137684
# 2017-08-08     7.171725
# 2017-08-09     5.258353
# 2017-08-10     5.291116
# 2017-08-11     4.945221
# 2017-08-12     5.735748
# 2017-08-13     4.679043
# 2017-08-14     5.036260
# 2017-08-15     4.802418
# 2017-08-16     3.225630
# 2017-08-17     1.864036
# 2017-08-18     2.220673
#                 ...
# 2020-03-16    48.541330
# 2020-03-17    48.392593
# 2020-03-18    51.053367
# 2020-03-19    51.765843
# 2020-03-20    52.457813
# 2020-03-21    52.478299
# 2020-03-22    51.836691
# ...

# %%
b.plot()

# %%
#you can change the plot size 
b.plot(figsize = (15,5))

# %%
k = pd.date_range('20170720',periods =1000)
df =pd.DataFrame(np.random.randn(1000),index = k)

# %%
df.plot()

# %%
plt.figure();df.plot()  # I read somewhere that plt.figure() is useful when there are multiple figures

# %%
s = pd.date_range('20170720',periods =1000)
df =pd.DataFrame(np.random.randn(1000,4),index = s,columns = list('ABCD'))

# %%
df
# Out:
#                    A         B         C         D
# 2017-07-20 -1.904375  1.745272  0.719058 -0.506895
# 2017-07-21 -1.764113 -0.401577 -2.783875  0.394956
# 2017-07-22 -0.616561 -0.694413 -0.818465  0.947443
# 2017-07-23 -0.246781  2.490164 -1.367972  0.677846
# 2017-07-24 -0.084975  0.107583 -0.301632  0.969949
# 2017-07-25 -0.536544 -0.288226  1.541345  0.258483
# 2017-07-26 -0.653739  0.615347 -0.744051 -1.800352
# 2017-07-27  0.400475  0.704586 -0.915030  0.701190
# 2017-07-28  0.242033  0.298520  0.381273  0.435941
# 2017-07-29  1.320214 -0.291726  1.469170  0.264658
# 2017-07-30 -2.469196 -0.946614 -1.021930  0.468987
# 2017-07-31 -1.601070 -0.102212 -1.073611  0.395710
# 2017-08-01 -0.175384 -0.207649 -0.035513  0.397242
# 2017-08-02  0.354474  1.530975 -1.810361  0.137024
# 2017-08-03 -0.264829  0.706710 -0.997150  0.202534
# 2017-08-04 -1.819317 -1.117651 -0.123906 -1.859745
# 2017-08-05 -1.970374 -0.275817 -0.629422  1.939240
# ...

# %%
df.cumsum()
# Out:
#                     A          B          C          D
# 2017-07-20  -1.904375   1.745272   0.719058  -0.506895
# 2017-07-21  -3.668488   1.343695  -2.064817  -0.111939
# 2017-07-22  -4.285049   0.649282  -2.883282   0.835504
# 2017-07-23  -4.531830   3.139447  -4.251254   1.513350
# 2017-07-24  -4.616805   3.247030  -4.552886   2.483299
# 2017-07-25  -5.153349   2.958804  -3.011541   2.741783
# 2017-07-26  -5.807088   3.574151  -3.755592   0.941431
# 2017-07-27  -5.406613   4.278738  -4.670622   1.642621
# 2017-07-28  -5.164580   4.577258  -4.289349   2.078562
# 2017-07-29  -3.844366   4.285532  -2.820178   2.343220
# 2017-07-30  -6.313562   3.338917  -3.842109   2.812207
# 2017-07-31  -7.914632   3.236705  -4.915720   3.207917
# 2017-08-01  -8.090016   3.029056  -4.951232   3.605159
# 2017-08-02  -7.735542   4.560032  -6.761593   3.742183
# 2017-08-03  -8.000371   5.266741  -7.758743   3.944717
# 2017-08-04  -9.819688   4.149090  -7.882649   2.084971
# ...

# %%
df.plot()

# %%
df.plot(figsize = (15,5))

# %%
k = pd.date_range('20170720',periods =1000)
df =pd.DataFrame(np.random.randn(1000,2),index = k,columns = list('AB'))

# %%
df['C'] = list((range(len(k))))

# %%
df
# Out:
#                    A         B    3    C
# 2017-07-20 -0.746886  0.513597    0    0
# 2017-07-21  0.438692  0.463392    1    1
# 2017-07-22  2.207589  1.624434    2    2
# 2017-07-23 -0.063837 -0.162980    3    3
# 2017-07-24 -1.838830  0.087444    4    4
# 2017-07-25  0.774994 -0.172091    5    5
# 2017-07-26 -0.266613  1.303134    6    6
# 2017-07-27  0.350635 -1.702603    7    7
# 2017-07-28  0.076163  1.311695    8    8
# 2017-07-29  0.233879 -0.984676    9    9
# 2017-07-30  0.381999 -0.227340   10   10
# 2017-07-31 -0.133169  0.773439   11   11
# 2017-08-01  0.289018  0.072464   12   12
# 2017-08-02  0.143621 -0.796352   13   13
# 2017-08-03  0.413027 -1.535166   14   14
# 2017-08-04  1.672407 -2.082167   15   15
# 2017-08-05 -0.154404 -1.411967   16   16
# 2017-08-06  0.413851  0.173743   17   17
# 2017-08-07  0.101031  0.673961   18   18
# 2017-08-08 -0.404295  0.523717   19   19
# 2017-08-09  0.555501 -0.729215   20   20
# 2017-08-10 -1.577215 -0.272507   21   21
# ...

# %%
df.plot(x = 'C',y ='A')

# %%
# There are various kinds of graphs such as bar,kde(density),df.hist,df.boxplot(),pie,area,scatter,hexbin etc

# %%
df.ix[5].plot(kind = 'bar')
# Out:
# C:\Users\user\anaconda_new\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   """Entry point for launching an IPython kernel.

# %%
df.ix[5].plot(kind = 'bar');plt.axhline(0,color = 'k')
#dont know what does that second command do but i can see a dark x axis

# %%
df.plot(kind = 'bar')
# To rectify this reduce data size

# %%
d = df.head(10)

# %%
d.plot(kind ='bar',stacked = True,figsize = (15,5))

# %%
d.plot(kind ='barh',stacked = True,figsize = (15,5))
#barh is horizontal

# %%
d.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027B730B5160>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027B74556C50>]], dtype=object)

# %%
d['A'].hist(color = 'K',bins = 20)
#k is color and bins is number of divisions

# %%
box = pd.DataFrame(np.random.randn(10,5))

# %%
box.boxplot()

# %%
box = pd.DataFrame(np.random.randn(10,2),index = np.random.randn(10),columns = ['col1','col2'])

# %%
box.groupby('col1').boxplot()

# This is worst but this is only to demonstrate that using boxplot we can actually draw the graphs for differnt groups
# Out:
# -1.432243         Axes(0.1,0.763636;0.235294x0.136364)
# -0.876882    Axes(0.382353,0.763636;0.235294x0.136364)
# -0.725097    Axes(0.664706,0.763636;0.235294x0.136364)
# -0.044163         Axes(0.1,0.559091;0.235294x0.136364)
# -0.024998    Axes(0.382353,0.559091;0.235294x0.136364)
#  0.142156    Axes(0.664706,0.559091;0.235294x0.136364)
#  0.550591         Axes(0.1,0.354545;0.235294x0.136364)
#  0.642344    Axes(0.382353,0.354545;0.235294x0.136364)
#  2.248200    Axes(0.664706,0.354545;0.235294x0.136364)
#  2.504655             Axes(0.1,0.15;0.235294x0.136364)
# dtype: object

# %%
df[:10].plot(kind = 'area',stacked = False)

# %%
df.plot(kind = 'hexbin',x = 'A',y ='B')
#this is hexagonal bin plot it takes even more arguments

# %%
abs(df[:4]).plot(kind = 'pie',subplots = True,figsize = (15,10))
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x0000027B7A5B1B70>,
# ...
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000027B7A6EA550>], dtype=object)

# %%
# Pie can also percentage by autopct keyword argument

# %%
# SCATTER MATRIX PLOT

# %%
from pandas.tools.plotting import scatter_matrix
df = pd.DataFrame(np.random.randn(1000,4),columns = list('ABCD'))

# %%
scatter_matrix(df,alpha = 0.2,figsize = (10,10),diagonal = 'kde')
# It is giving warning but that module is not found
# Out:
# C:\Users\user\anaconda_new\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000027B7C112358>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000027B7D994240>]], dtype=object)

# %%
df.plot(kind = 'kde',figsize = (15,7))

# %%
# Andrews curves are used to plot multivariate data using whose samples as coefficients of a fourier series

# Parallel coordinates is also one such technique for plotting multivariate data

# Lag plot it allows you to see clusters of data

# bootstrap is to assess uncertainity in data like mean etc

# autocorrelation plot is to measure uncertainities of timedata

# %%
# There are techniques to scale give logy = true scale will be exponential

# controlling legend which i donot fully understand

# %%
# plotting secondary data like df.A.plot()

# keeping subplots true will enable each column to be printed on different graphs

# %%
# Trellis plotting interface which I didnt covered due to lack of time
